# %% [markdown]
# Реализуйте класс очередь на основе списка и на основе deque. Сравните время и затраты памяти на каждую структуру при последовательном добавлении и извлечении элементов.

# %%
from collections import deque
import matplotlib.pyplot as plt
import time
import sys

class ListQueue:
    def __init__(self):
        self.queue = []

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.pop(0)
    
    def size(self):
        return len(self.queue)


class DequeQueue:
    def __init__(self):
        self.queue = deque()

    def enqueue(self, item):
        self.queue.append(item)

    def dequeue(self):
        if len(self.queue) < 1:
            return None
        return self.queue.popleft()

    def size(self):
        return len(self.queue)


def measure_performance(queue_class, operations):
    start_time = time.time()
    memory_before = sys.getsizeof(queue_class.queue)

    for i in range(operations):
        queue_class.enqueue(i)

    for i in range(operations):
        queue_class.dequeue()

    end_time = time.time()
    memory_after = sys.getsizeof(queue_class.queue)

    time_taken = end_time - start_time
    memory_used = memory_after - memory_before

    return time_taken, memory_used


operations = 100000
list_queue = ListQueue()
deque_queue = DequeQueue()

list_performance = measure_performance(list_queue, operations)
deque_performance = measure_performance(deque_queue, operations)

list_performance, deque_performance
# Out:
# ((2.693557024002075, 0), (0.05482840538024902, 0))

# %%
def measure_individual_operations_and_memory_queue(queue_class, operations):
    enqueue_times = []
    dequeue_times = []
    enqueue_memory = []
    dequeue_memory = []

    for i in range(operations):
        start_time = time.time()
        queue_class.enqueue(i)
        end_time = time.time()
        enqueue_times.append(end_time - start_time)
        enqueue_memory.append(sys.getsizeof(queue_class.queue))

    for i in range(operations):
        start_time = time.time()
        queue_class.dequeue()
        end_time = time.time()
        dequeue_times.append(end_time - start_time)
        dequeue_memory.append(sys.getsizeof(queue_class.queue))

    return enqueue_times, dequeue_times, enqueue_memory, dequeue_memory

operations = 100000


list_enqueue_times, list_dequeue_times, list_enqueue_memory, list_dequeue_memory = measure_individual_operations_and_memory_queue(list_queue, operations)
deque_enqueue_times, deque_dequeue_times, deque_enqueue_memory, deque_dequeue_memory = measure_individual_operations_and_memory_queue(deque_queue, operations)


plt.figure(figsize=(12, 12))

# Время операций добавления в очередь
plt.subplot(2, 2, 1)
plt.plot(range(operations), list_enqueue_times, color='blue', label='Время добавления в ListQueue')
plt.plot(range(operations), deque_enqueue_times, color='red', label='Время добавления в DequeQueue')
plt.title('Время операций добавления')
plt.xlabel('Номер операции')
plt.ylabel('Время (секунды)')
plt.legend()

# Время операций извлечения из очереди
plt.subplot(2, 2, 2)
plt.plot(range(operations), list_dequeue_times, color='blue', label='Время извлечения из ListQueue')
plt.plot(range(operations), deque_dequeue_times, color='red', label='Время извлечения из DequeQueue')
plt.title('Время операций извлечения')
plt.xlabel('Номер операции')
plt.ylabel('Время (секунды)')
plt.legend()

# Использование памяти во время операций добавления
plt.subplot(2, 2, 3)
plt.plot(range(operations), list_enqueue_memory, color='blue', label='Использование памяти при добавлении в ListQueue')
plt.plot(range(operations), deque_enqueue_memory, color='red', label='Использование памяти при добавлении в DequeQueue')
plt.title('Использование памяти во время добавления')
plt.xlabel('Номер операции')
plt.ylabel('Использование памяти (байты)')
plt.legend()

# Использование памяти во время операций извлечения
plt.subplot(2, 2, 4)
plt.plot(range(operations), list_dequeue_memory, color='blue', label='Использование памяти при извлечении из ListQueue')
plt.plot(range(operations), deque_dequeue_memory, color='red', label='Использование памяти при извлечении из DequeQueue')
plt.title('Использование памяти во время извлечения')
plt.xlabel('Номер операции')
plt.ylabel('Использование памяти (байты)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Реализуйте класс стек на основе списка и на основе deque. Сравните время и затраты памяти на каждую структуру при последовательном добавлении и извлечении элементов.

# %%
class ListStack:
    def __init__(self):
        self.stack = []

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if len(self.stack) < 1:
            return None
        return self.stack.pop()

    def size(self):
        return len(self.stack)


class DequeStack:
    def __init__(self):
        self.stack = deque()

    def push(self, item):
        self.stack.append(item)

    def pop(self):
        if len(self.stack) < 1:
            return None
        return self.stack.pop()

    def size(self):
        return len(self.stack)


def measure_performance_stack(stack_class, operations):
    start_time = time.time()
    memory_before = sys.getsizeof(stack_class.stack)

    for i in range(operations):
        stack_class.push(i)

    for i in range(operations):
        stack_class.pop()

    end_time = time.time()
    memory_after = sys.getsizeof(stack_class.stack)

    time_taken = end_time - start_time
    memory_used = memory_after - memory_before

    return time_taken, memory_used


operations = 10000
list_stack = ListStack()
deque_stack = DequeStack()

list_stack_performance = measure_performance_stack(list_stack, operations)
deque_stack_performance = measure_performance_stack(deque_stack, operations)

list_stack_performance, deque_stack_performance
# Out:
# ((0.0040283203125, 0), (0.00396418571472168, 0))

# %%
def measure_individual_operations_and_memory_stack(stack_class, operations):
    push_times = []
    pop_times = []
    push_memory = []
    pop_memory = []

    for i in range(operations):
        start_time = time.time()
        stack_class.push(i)
        end_time = time.time()
        push_times.append(end_time - start_time)
        push_memory.append(sys.getsizeof(stack_class.stack))

    for i in range(operations):
        start_time = time.time()
        stack_class.pop()
        end_time = time.time()
        pop_times.append(end_time - start_time)
        pop_memory.append(sys.getsizeof(stack_class.stack))

    return push_times, pop_times, push_memory, pop_memory

operations = 100000


list_push_times, list_pop_times, list_push_memory, list_pop_memory = measure_individual_operations_and_memory_stack(list_stack, operations)
deque_push_times, deque_pop_times, deque_push_memory, deque_pop_memory = measure_individual_operations_and_memory_stack(deque_stack, operations)

plt.figure(figsize=(12, 12))

plt.subplot(2, 2, 1)
plt.plot(range(operations), list_push_times, color='blue', label='ListStack Push Time')
plt.plot(range(operations), deque_push_times, color='red', label='DequeStack Push Time')
plt.title('Push Operation Times')
plt.xlabel('Operation Number')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(2, 2, 2)
plt.plot(range(operations), list_pop_times, color='blue', label='ListStack Pop Time')
plt.plot(range(operations), deque_pop_times, color='red', label='DequeStack Pop Time')
plt.title('Pop Operation Times')
plt.xlabel('Operation Number')
plt.ylabel('Time (seconds)')
plt.legend()

plt.subplot(2, 2, 3)
plt.plot(range(operations), list_push_memory, color='blue', label='ListStack Push Memory')
plt.plot(range(operations), deque_push_memory, color='red', label='DequeStack Push Memory')
plt.title('Memory Usage During Push Operations')
plt.xlabel('Operation Number')
plt.ylabel('Memory Usage (bytes)')
plt.legend()

plt.subplot(2, 2, 4)
plt.plot(range(operations), list_pop_memory, color='blue', label='ListStack Pop Memory')
plt.plot(range(operations), deque_pop_memory, color='red', label='DequeStack Pop Memory')
plt.title('Memory Usage During Pop Operations')
plt.xlabel('Operation Number')
plt.ylabel('Memory Usage (bytes)')
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Реализуйте класс Односвязный список. Найдите минимальный элемент в нем. Сравните с временем поиска минимального элемента при использовании списка.

# %%
class Node:
    def __init__(self, value):
        self.value = value
        self.next = None


class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def append(self, value):
        if not self.head:
            self.head = Node(value)
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = Node(value)

    def find_min(self):
        if not self.head:
            return None

        min_val = self.head.value
        current = self.head
        while current:
            if current.value < min_val:
                min_val = current.value
            current = current.next
        return min_val


def measure_time_to_find_min(function_to_find_min):
    start_time = time.time()
    min_value = function_to_find_min()
    end_time = time.time()
    return min_value, end_time - start_time


def measure_time_to_find_min_sll(sll, size):
    sll.head = None  
    for i in range(size):
        sll.append(i)

    start_time = time.time()
    sll.find_min()
    end_time = time.time()

    return end_time - start_time

def measure_time_to_find_min_list(lst, size):
    start_time = time.time()
    min(lst[:size])
    end_time = time.time()
    return end_time - start_time



elements = [i for i in range(100000)]
singly_linked_list = SinglyLinkedList()
regular_list = elements[:]

for element in elements:
    singly_linked_list.append(element)

min_value_singly_linked_list, time_singly_linked_list = measure_time_to_find_min(singly_linked_list.find_min)
min_value_regular_list, time_regular_list = measure_time_to_find_min(lambda: min(regular_list))

structures = ['Singly Linked List', 'Regular List']
times = [time_singly_linked_list, time_regular_list]

plt.figure(figsize=(8, 6))
plt.bar(structures, times, color=['blue', 'green'])
plt.title('Comparison of Time to Find Minimum Element')
plt.ylabel('Time (seconds)')
plt.xlabel('Data Structure')
plt.show()



min_value_singly_linked_list, time_singly_linked_list, min_value_regular_list, time_regular_list

reduced_sizes = [100, 500, 1000, 2000, 3000, 4000, 5000]
reduced_times_sll = []
reduced_times_list = []

for size in reduced_sizes:
    reduced_times_sll.append(measure_time_to_find_min_sll(singly_linked_list, size))
    reduced_times_list.append(measure_time_to_find_min_list(regular_list, size))

plt.figure(figsize=(12, 6))
plt.plot(reduced_sizes, reduced_times_sll, label='Singly Linked List', marker='o')
plt.plot(reduced_sizes, reduced_times_list, label='Regular List', marker='x')
plt.title('Time to Find Minimum Element at Different Sizes (Reduced)')
plt.xlabel('Number of Elements')
plt.ylabel('Time (seconds)')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# c:\Users\79251\Desktop\ВУЗ\5 семестр\Алгоритмы и структуры данных\algorims_sem5\control_work_4.ipynb Ячейка 8 line 6
#      <a href='vscode-notebook-cell:/c%3A/Users/79251/Desktop/%D0%92%D0%A3%D0%97/5%20%D1%81%D0%B5%D0%BC%D0%B5%D1%81%D1%82%D1%80/%D0%90%D0%BB%D0%B3%D0%BE%D1%80%D0%B8%D1%82%D0%BC%D1%8B%20%D0%B8%20%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%82%D1%83%D1%80%D1%8B%20%D0%B4%D0%B0%D0%BD%D0%BD%D1%8B%D1%85/algorims_sem5/control_work_4.ipynb#W5sZmlsZQ%3D%3D?line=60'>61</a> regular_list = elements[:]
# ...

# %% [markdown]
# Реализуйте класс Двусвязный список.

# %%
class DoubleNode:
    def __init__(self, value):
        self.value = value
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None
        self.tail = None

    def append(self, value):
        new_node = DoubleNode(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            self.tail.next = new_node
            new_node.prev = self.tail
            self.tail = new_node

    def prepend(self, value):
        new_node = DoubleNode(value)
        if not self.head:
            self.head = new_node
            self.tail = new_node
        else:
            new_node.next = self.head
            self.head.prev = new_node
            self.head = new_node

    def delete(self, value):
        current = self.head
        while current:
            if current.value == value:
                if current.prev:
                    current.prev.next = current.next
                if current.next:
                    current.next.prev = current.prev
                if current == self.head:
                    self.head = current.next
                if current == self.tail:
                    self.tail = current.prev
                return
            current = current.next

    def __str__(self):
        values = []
        current = self.head
        while current:
            values.append(str(current.value))
            current = current.next
        return ' <-> '.join(values)

dll = DoublyLinkedList()
dll.append(1)
dll.append(2)
dll.append(3)
dll.prepend(0)
print("Doubly Linked List after appending and prepending:", dll)
dll.delete(2)
print("Doubly Linked List after deleting a value:", dll)
# Out:
# Doubly Linked List after appending and prepending: 0 <-> 1 <-> 2 <-> 3
# Doubly Linked List after deleting a value: 0 <-> 1 <-> 3
